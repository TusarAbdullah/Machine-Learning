# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_excel("shop.xlsx")

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Marketing Spend  50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Transport        49 non-null     float64
#  3   Area             50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
df.isnull()
# Out:
#     Marketing Spend  Administration  Transport   Area  Profit
# 0             False           False      False  False   False
# 1             False           False      False  False   False
# 2             False           False      False  False   False
# 3             False           False      False  False   False
# 4             False           False      False  False   False
# 5             False           False      False  False   False
# 6             False           False      False  False   False
# 7             False           False      False  False   False
# 8             False           False      False  False   False
# 9             False           False      False  False   False
# 10            False           False      False  False   False
# 11            False           False      False  False   False
# 12            False           False      False  False   False
# 13            False           False      False  False   False
# ...

# %%
df.isnull().sum()
# Out:
# Marketing Spend    0
# Administration     0
# Transport          1
# Area               0
# Profit             0
# dtype: int64

# %% [markdown]
# # Measures of Central Tendency

# %%
df.Transport.mean()
# Out:
# 215331.7324489796

# %%
df.Transport.median()
# Out:
# 214634.81

# %%
df.Area.mode()
# Out:
# 0      Ctg
# 1    Dhaka
# Name: Area, dtype: object

# %%
df.Transport.mode()
# Out:
# 0    0.0
# Name: Transport, dtype: float64

# %%
df.Profit.mode()
# Out:
# 0      14681.40
# 1      35673.41
# 2      42559.73
# 3      49490.75
# 4      64926.08
# 5      65200.33
# 6      69758.98
# 7      71498.49
# 8      77798.83
# 9      78239.91
# 10     81005.76
# 11     81229.06
# 12     89949.14
# 13     90708.19
# 14     96479.51
# 15     96712.80
# 16     96778.92
# 17     97427.84
# 18     97483.56
# 19     99937.59
# 20    101004.64
# 21    103282.38
# 22    105008.31
# 23    105733.54
# 24    107404.34
# 25    108552.04
# 26    108733.99
# 27    110352.25
# 28    111313.02
# 29    118474.03
# 30    122776.86
# 31    124266.90
# 32    125370.37
# 33    126992.93
# 34    129917.04
# 35    132602.65
# 36    134307.35
# 37    141585.52
# 38    144259.40
# 39    146121.95
# 40    149759.96
# 41    152211.77
# 42    155752.60
# 43    156122.51
# 44    156991.12
# 45    166187.94
# 46    182901.99
# 47    191050.39
# 48    191792.06
# 49    192261.83
# Name: Profit, dtype: float64

# %%
df.describe()
# Out:
#        Marketing Spend  Administration      Transport         Profit
# count        50.000000       50.000000      49.000000      50.000000
# mean      73721.615600   121344.639600  215331.732449  112012.639200
# std       45902.256482    28017.802755  119665.391550   40306.180338
# min           0.000000    51283.140000       0.000000   14681.400000
# 25%       39936.370000   103730.875000  134050.070000   90138.902500
# 50%       73051.080000   122699.795000  214634.810000  107978.190000
# 75%      101602.800000   144842.180000  299737.290000  139765.977500
# max      165349.200000   182645.560000  471784.100000  192261.830000

# %%
# !pip install seaborn
# Out:
# ...
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

# %%
sns.histplot(df[["Profit"]])
# Out:
# <Axes: ylabel='Count'>

# %%
df.corr() #corr() means ekta column er sathe onno column er relation buzaitese
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df.corr() #corr() means ekta column er sathe onno column er relation buzaitese
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True)
plt.savefig("mominul.png")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 2
#       1 plt.figure(figsize=(10,10))
# ----> 2 sns.heatmap(df.corr(),annot=True)
#       3 plt.savefig("mominul.png")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
# ...

# %% [markdown]
# # Handle NAN value (NAN == NULL)

# %%
Mean_Transport = df.Transport.mean()

# %%
Mean_Transport
# Out:
# 215331.7324489796

# %%
df.isnull().sum()
# Out:
# Marketing Spend    0
# Administration     0
# Transport          1
# Area               0
# Profit             0
# dtype: int64

# %%
df.Transport = df.Transport.fillna(Mean_Transport)

# %%
df.isnull().sum()
# Out:
# Marketing Spend    0
# Administration     0
# Transport          0
# Area               0
# Profit             0
# dtype: int64

# %%
df.Transport.iloc[19]
# Out:
# 215331.7324489796

# %%
df1 = df.copy()
df2 = df.copy()
df3 = df.copy()
df4 = df.copy()
df5 = df.copy()
df6 = df.copy()
df7 = df.copy()
df8 = df.copy()
df9 = df.copy()
df10 = df.copy()
df11 = df.copy()
df12 = df.copy()


df20 = df.copy()
df21 = df.copy()

df20 = df.copy()
df31 = df.copy()
df32 = df.copy()
df33 = df.copy()

# %% [markdown]
# # Without Encoding

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
area1 = df.Area.unique()

# %%
area1
# Out:
# array(['Dhaka', 'Ctg', 'Rangpur'], dtype=object)

# %%
df.Area = df.Area.replace(['Dhaka', 'Ctg', 'Rangpur'],[1,2,3])

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport  Area     Profit
# 0        114523.61       136897.80  471784.10     1  192261.83
# 1        162597.70       151377.59  443898.53     2  191792.06
# 2        153441.51       101145.55  407934.54     3  191050.39
# 3        144372.41       118671.85  383199.62     1  182901.99
# 4        142107.34        91391.77  366168.42     3  166187.94

# %% [markdown]
# # Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df1.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df1.Area = le.fit_transform(df1.Area)

# %%
df1.head()
# Out:
#    Marketing Spend  Administration  Transport  Area     Profit
# 0        114523.61       136897.80  471784.10     1  192261.83
# 1        162597.70       151377.59  443898.53     0  191792.06
# 2        153441.51       101145.55  407934.54     2  191050.39
# 3        144372.41       118671.85  383199.62     1  182901.99
# 4        142107.34        91391.77  366168.42     2  166187.94

# %% [markdown]
# # Using Loop --- for multiple column

# %%
df2.columns
# Out:
# Index(['Marketing Spend', 'Administration', 'Transport', 'Area', 'Profit'], dtype='object')

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
for col in df2.columns:
    if df2[col].dtype == np.number:
        continue
    else:
        df2[col] = le.fit_transform(df2[col])

# %%
 df2.head()
# Out:
#    Marketing Spend  Administration  Transport  Area     Profit
# 0        114523.61       136897.80  471784.10     1  192261.83
# 1        162597.70       151377.59  443898.53     0  191792.06
# 2        153441.51       101145.55  407934.54     2  191050.39
# 3        144372.41       118671.85  383199.62     1  182901.99
# 4        142107.34        91391.77  366168.42     2  166187.94

# %% [markdown]
# # Another Way

# %%
from pandas.core.dtypes.common import is_numeric_dtype

# %%
for i in df3.columns:
    if is_numeric_dtype(df3[i]):
        continue
    else:
        df3[i] = le.fit_transform(df3[i])

# %%
df3.head()
# Out:
#    Marketing Spend  Administration  Transport  Area     Profit
# 0        114523.61       136897.80  471784.10     1  192261.83
# 1        162597.70       151377.59  443898.53     0  191792.06
# 2        153441.51       101145.55  407934.54     2  191050.39
# 3        144372.41       118671.85  383199.62     1  182901.99
# 4        142107.34        91391.77  366168.42     2  166187.94

# %% [markdown]
# # One Hot Encoding

# %%
dummy = pd.get_dummies(df4['Area'], columns=df4.Area.unique)

# %%
dummy.head()
# Out:
#      Ctg  Dhaka  Rangpur
# 0  False   True    False
# 1   True  False    False
# 2  False  False     True
# 3  False   True    False
# 4  False  False     True

# %%
df4.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df4.drop('Area',axis=1,inplace=True)

# %%
df4.head()
# Out:
#    Marketing Spend  Administration  Transport     Profit
# 0        114523.61       136897.80  471784.10  192261.83
# 1        162597.70       151377.59  443898.53  191792.06
# 2        153441.51       101145.55  407934.54  191050.39
# 3        144372.41       118671.85  383199.62  182901.99
# 4        142107.34        91391.77  366168.42  166187.94

# %% [markdown]
# # Dummy variable Trap

# %%
dummy = pd.get_dummies(df5['Area'],columns=df5.Area.unique,drop_first=True,prefix='Area')

# %%
dummy.head()
# Out:
#    Area_Dhaka  Area_Rangpur
# 0        True         False
# 1       False         False
# 2       False          True
# 3        True         False
# 4       False          True

# %%
df6 = pd.concat([df4,dummy],axis=1)

# %%
df6.head()
# Out:
#    Marketing Spend  Administration  Transport     Profit  Area_Dhaka  \
# 0        114523.61       136897.80  471784.10  192261.83        True
# 1        162597.70       151377.59  443898.53  191792.06       False
# 2        153441.51       101145.55  407934.54  191050.39       False
# 3        144372.41       118671.85  383199.62  182901.99        True
# 4        142107.34        91391.77  366168.42  166187.94       False
#
#    Area_Rangpur
# 0         False
# 1         False
# 2          True
# 3         False
# 4          True

# %% [markdown]
# # amar kora

# %%
#dummy = pd.get_dummies(df4['Area'], dtype=int)
dummy = pd.get_dummies(df12['Area'], columns=df12.Area.unique,dtype=int)

# %%
dummy.head()
# Out:
#    Ctg  Dhaka  Rangpur
# 0    0      1        0
# 1    1      0        0
# 2    0      0        1
# 3    0      1        0
# 4    0      0        1

# %%
dummy = pd.get_dummies(df12['Area'], dtype=int) ##################

# %%
dummy.head()
# Out:
#    Ctg  Dhaka  Rangpur
# 0    0      1        0
# 1    1      0        0
# 2    0      0        1
# 3    0      1        0
# 4    0      0        1

# %%
dummy = pd.get_dummies(df11['Area'],drop_first=True,prefix='Area',dtype=int)

# %%
dummy.head()
# Out:
#    Area_Dhaka  Area_Rangpur
# 0           1             0
# 1           0             0
# 2           0             1
# 3           1             0
# 4           0             1

# %%
df11 = pd.concat([df11,dummy],axis=1)

# %%
df11.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit  Area_Dhaka  \
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83           1
# 1        162597.70       151377.59  443898.53      Ctg  191792.06           0
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39           0
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99           1
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94           0
#
#    Area_Rangpur
# 0             0
# 1             0
# 2             1
# 3             0
# 4             1

# %%
df11.drop('Area',axis=1,inplace=True)

# %%
df11.head()
# Out:
#    Marketing Spend  Administration  Transport     Profit  Area_Dhaka  \
# 0        114523.61       136897.80  471784.10  192261.83           1
# 1        162597.70       151377.59  443898.53  191792.06           0
# 2        153441.51       101145.55  407934.54  191050.39           0
# 3        144372.41       118671.85  383199.62  182901.99           1
# 4        142107.34        91391.77  366168.42  166187.94           0
#
#    Area_Rangpur
# 0             0
# 1             0
# 2             1
# 3             0
# 4             1

# %%
dummy = pd.get_dummies(df20['Area'],drop_first=True,prefix='Area',dtype=int)

# %%
dummy.head()
# Out:
#    Area_Dhaka  Area_Rangpur
# 0           1             0
# 1           0             0
# 2           0             1
# 3           1             0
# 4           0             1

# %%
df21.drop('Area',axis=1,inplace=True)

# %%
df21.head()
# Out:
#    Marketing Spend  Administration  Transport     Profit
# 0        114523.61       136897.80  471784.10  192261.83
# 1        162597.70       151377.59  443898.53  191792.06
# 2        153441.51       101145.55  407934.54  191050.39
# 3        144372.41       118671.85  383199.62  182901.99
# 4        142107.34        91391.77  366168.42  166187.94

# %%
df21 = pd.concat([df21,dummy],axis=1)

# %%
df21.head()
# Out:
#    Marketing Spend  Administration  Transport     Profit  Area_Dhaka  \
# 0        114523.61       136897.80  471784.10  192261.83           1
# 1        162597.70       151377.59  443898.53  191792.06           0
# 2        153441.51       101145.55  407934.54  191050.39           0
# 3        144372.41       118671.85  383199.62  182901.99           1
# 4        142107.34        91391.77  366168.42  166187.94           0
#
#    Area_Rangpur
# 0             0
# 1             0
# 2             1
# 3             0
# 4             1

# %%
dummy.head()
# Out:
#    Area_Dhaka  Area_Rangpur
# 0           1             0
# 1           0             0
# 2           0             1
# 3           1             0
# 4           0             1

# %%
df31.drop('Area',axis=1,inplace=True)

# %%
df31.head()
# Out:
#    Marketing Spend  Administration  Transport     Profit
# 0        114523.61       136897.80  471784.10  192261.83
# 1        162597.70       151377.59  443898.53  191792.06
# 2        153441.51       101145.55  407934.54  191050.39
# 3        144372.41       118671.85  383199.62  182901.99
# 4        142107.34        91391.77  366168.42  166187.94

# %%
df32 = pd.concat([df31,dummy],axis=1)

# %%
df32.head()
# Out:
#    Marketing Spend  Administration  Transport     Profit  Area_Dhaka  \
# 0        114523.61       136897.80  471784.10  192261.83           1
# 1        162597.70       151377.59  443898.53  191792.06           0
# 2        153441.51       101145.55  407934.54  191050.39           0
# 3        144372.41       118671.85  383199.62  182901.99           1
# 4        142107.34        91391.77  366168.42  166187.94           0
#
#    Area_Rangpur
# 0             0
# 1             0
# 2             1
# 3             0
# 4             1

# %% [markdown]
# # One hot encoding using Loop

# %%
df7.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
cols = ['Area']
for col in cols:
    dummy = pd.get_dummies(df7[col],drop_first=True,prefix='Área')
    df8 = pd.concat([df7,dummy],axis=1).drop(col,axis=1)
    
df8.head()
# Out:
#    Marketing Spend  Administration  Transport     Profit  Área_Dhaka  \
# 0        114523.61       136897.80  471784.10  192261.83        True
# 1        162597.70       151377.59  443898.53  191792.06       False
# 2        153441.51       101145.55  407934.54  191050.39       False
# 3        144372.41       118671.85  383199.62  182901.99        True
# 4        142107.34        91391.77  366168.42  166187.94       False
#
#    Área_Rangpur
# 0         False
# 1         False
# 2          True
# 3         False
# 4          True

# %%
cols
# Out:
# ['Area']

# %% [markdown]
# # Ordinal Encoding

# %%
city = df9.Area.unique()

# %%
city
# Out:
# array(['Dhaka', 'Ctg', 'Rangpur'], dtype=object)

# %%
df9.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
from sklearn.preprocessing import OrdinalEncoder
od = OrdinalEncoder(categories=[city])

# %%
encoded_values = od.fit_transform(df9[['Area']])

# %%
encoded_values
# Out:
# array([[0.],
#        [1.],
#        [2.],
#        [0.],
#        [2.],
#        [0.],
#        [1.],
#        [2.],
#        [0.],
#        [1.],
#        [2.],
#        [1.],
#        [2.],
#        [1.],
#        [2.],
#        [0.],
#        [1.],
#        [0.],
#        [2.],
#        [0.],
#        [1.],
#        [0.],
#        [2.],
#        [2.],
#        [0.],
#        [1.],
#        [2.],
#        [0.],
#        [2.],
#        [0.],
#        [2.],
#        [0.],
#        [1.],
#        [2.],
#        [1.],
#        [0.],
#        [2.],
#        [1.],
#        [0.],
#        [1.],
#        [1.],
#        [2.],
#        [1.],
#        [0.],
#        [1.],
#        [0.],
#        [2.],
#        [1.],
#        [0.],
#        [1.]])

# %%
encoded_values = pd.DataFrame(encoded_values,columns=['Area'])

# %%
encoded_values.head()
# Out:
#    Area
# 0   0.0
# 1   1.0
# 2   2.0
# 3   0.0
# 4   2.0

# %%
df9 = pd.concat([df9.drop('Area',axis=1),encoded_values],axis=1)

# %%
df9.head()
# Out:
#    Marketing Spend  Administration  Transport     Profit  Area
# 0        114523.61       136897.80  471784.10  192261.83   0.0
# 1        162597.70       151377.59  443898.53  191792.06   1.0
# 2        153441.51       101145.55  407934.54  191050.39   2.0
# 3        144372.41       118671.85  383199.62  182901.99   0.0
# 4        142107.34        91391.77  366168.42  166187.94   2.0

# %%
df9.corr() #corr() means ekta column er sathe onno column er relation buzaitese
# Out:
#                  Marketing Spend  Administration  Transport    Profit  \
# Marketing Spend         1.000000        0.230437   0.718001  0.937948
# Administration          0.230437        1.000000   0.009402  0.200717
# Transport               0.718001        0.009402   1.000000  0.781996
# Profit                  0.937948        0.200717   0.781996  1.000000
# Area                    0.037930        0.003026   0.097937  0.048471
#
#                      Area
# Marketing Spend  0.037930
# Administration   0.003026
# Transport        0.097937
# Profit           0.048471
# Area             1.000000

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True)
plt.savefig("mominul.png")

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df9.corr(),annot=True)
plt.savefig("Tepu.png")
